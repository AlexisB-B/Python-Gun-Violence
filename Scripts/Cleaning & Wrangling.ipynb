# %% [markdown]
# # Import Libraries & Data

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(r'C:\Users\alexi\OneDrive\Gun Violence\Data\Original Data\gun-violence-data_01-2013_03-2018.csv', index_col = False)

# %%
# create path
path = r'C:\Users\alexi\OneDrive\Gun Violence'

# %%
path
# Out:
# 'C:\\Users\\alexi\\OneDrive\\Gun Violence'

# %% [markdown]
# # Explore & Wrangle Data

# %%
df.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
# Check for mixed types
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# address
# source_url
# gun_stolen
# gun_type
# incident_characteristics
# location_description
# notes
# participant_age
# participant_age_group
# participant_gender
# participant_name
# participant_relationship
# participant_status
# participant_type
# sources

# %%
# check data types
df.dtypes
# Out:
# incident_id                      int64
# date                            object
# state                           object
# city_or_county                  object
# address                         object
# n_killed                         int64
# n_injured                        int64
# incident_url                    object
# source_url                      object
# incident_url_fields_missing       bool
# congressional_district         float64
# gun_stolen                      object
# gun_type                        object
# incident_characteristics        object
# latitude                       float64
# location_description            object
# longitude                      float64
# n_guns_involved                float64
# notes                           object
# participant_age                 object
# participant_age_group           object
# participant_gender              object
# participant_name                object
# participant_relationship        object
# ...

# %%
# dropping columns with PII or that are irrelevant to project
df=df.drop(columns=['participant_name', 'sources', 'incident_url', 'source_url', 'address', 'incident_url_fields_missing', 'notes'])

# %%
df.head()
# Out:
#    incident_id        date           state city_or_county  n_killed  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport         0
# 1       460726  2013-01-01      California      Hawthorne         1
# 2       478855  2013-01-01            Ohio         Lorain         1
# 3       478925  2013-01-05        Colorado         Aurora         4
# 4       478959  2013-01-07  North Carolina     Greensboro         2
#
#    n_injured  congressional_district              gun_stolen  \
# 0          4                    14.0                     NaN
# 1          3                    43.0                     NaN
# 2          3                     9.0  0::Unknown||1::Unknown
# 3          0                     6.0                     NaN
# 4          2                     6.0  0::Unknown||1::Unknown
#
#                  gun_type                           incident_characteristics  \
# 0                     NaN  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# ...

# %%
# rename columns
df.rename(columns = {'n_killed' : 'count_killed', 'n_injured' : 'count_injured', 'gun_stolen' : 'stolen_gun', 'n_guns_involved' : 'count_guns_involved', }, inplace = True)

# %%
df.head(5)
# Out:
#    incident_id        date           state city_or_county  count_killed  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport             0
# 1       460726  2013-01-01      California      Hawthorne             1
# 2       478855  2013-01-01            Ohio         Lorain             1
# 3       478925  2013-01-05        Colorado         Aurora             4
# 4       478959  2013-01-07  North Carolina     Greensboro             2
#
#    count_injured  congressional_district              stolen_gun  \
# 0              4                    14.0                     NaN
# 1              3                    43.0                     NaN
# 2              3                     9.0  0::Unknown||1::Unknown
# 3              0                     6.0                     NaN
# 4              2                     6.0  0::Unknown||1::Unknown
#
#                  gun_type                           incident_characteristics  \
# ...

# %%
# check for missing values
df.isnull().sum()
# Out:
# incident_id                      0
# date                             0
# state                            0
# city_or_county                   0
# count_killed                     0
# count_injured                    0
# congressional_district       11944
# stolen_gun                   99498
# gun_type                     99451
# incident_characteristics       326
# latitude                      7923
# location_description        197588
# longitude                     7923
# count_guns_involved          99451
# participant_age              92298
# participant_age_group        42119
# participant_gender           36362
# participant_relationship    223903
# participant_status           27626
# participant_type             24863
# state_house_district         38772
# state_senate_district        32335
# dtype: int64

# %%
# Checking for full duplicates
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [incident_id, date, state, city_or_county, count_killed, count_injured, congressional_district, stolen_gun, gun_type, incident_characteristics, latitude, location_description, longitude, count_guns_involved, participant_age, participant_age_group, participant_gender, participant_relationship, participant_status, participant_type, state_house_district, state_senate_district]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# no duplicates

# %% [markdown]
# ## Descriptive Stats

# %%
df.describe()
# Out:
#         incident_id   count_killed  count_injured  congressional_district  \
# count  2.396770e+05  239677.000000  239677.000000           227733.000000
# mean   5.593343e+05       0.252290       0.494007                8.001265
# std    2.931287e+05       0.521779       0.729952                8.480835
# min    9.211400e+04       0.000000       0.000000                0.000000
# 25%    3.085450e+05       0.000000       0.000000                2.000000
# 50%    5.435870e+05       0.000000       0.000000                5.000000
# 75%    8.172280e+05       0.000000       1.000000               10.000000
# max    1.083472e+06      50.000000      53.000000               53.000000
#
#             latitude      longitude  count_guns_involved  \
# count  231754.000000  231754.000000        140226.000000
# mean       37.546598     -89.338348             1.372442
# std         5.130763      14.359546             4.678202
# min        19.111400    -171.429000             1.000000
# ...

# %% [markdown]
# # Export

# %%
df.to_csv(os.path.join(path, 'Data','Prepared Data', 'firstclean'))
